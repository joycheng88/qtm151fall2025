# %% [markdown]
# # <span style="color:red"> QTM 151 - Quiz 1 </span>

# %% [markdown]
# ## Submit as an HTML file
# ## Quiz is open 11:30am to 12:20pm

# %% [markdown]
# <font size="5">
#
# Print your name below

# %%
# Write your answer here
print("Jiuyi (Joy) Cheng")
# Out:
# Jiuyi (Joy) Cheng

# %% [markdown]
# <font size = "5" >
# This quiz is open book
#
# - You can use the lecture notes
# - You will get partial credit for attempting the questions
# - To get full credit, the code should work as intended
# - You should <span style="color:red"> NOT </span> communicate with other students
#
# Print the following message: <br>
#
# "I will abide by Emory's code of conduct"

# %%
# Write your answer here:
print("I will abide by Emory's code of conduct")
# Out:
# I will abide by Emory's code of conduct

# %%
print("For some problems below, I have provided multiple solutions. \nI HAVE NOT commented out the alternative solutions, so multiple output will be displayed.")
# Out:
# For some problems below, I have provided multiple solutions.
# I HAVE NOT commented out the alternative solutions, so multiple output will be displayed.

# %% [markdown]
# <font size = "5">
#
# Import the libraries "numpy", "matplotlib.pyplot", and "pandas"

# %%
import numpy as np 
import matplotlib.pyplot as plt 
import pandas as pd

# %% [markdown]
# <font size = "5">
#
# 1. IF/ELIF/ELSE statements
#
# <font size = "3">
#
# - In the beginning of the code cell below, two lists are created, where element 0 is one of two random choices:
# ```python
# list_p = ["Introduction"/"Intro", "to", "Python"]
# list_r = ["Introduction"/"Intro", "to", "R"]
# ```
#
# - Create a new variable ``` keyword = "Introduction" ```
# - Create an if/elif/else block that tests whether ``` keyword ``` is part of either <br>
# list.  Depending on the outcome (belongs to list_p, belongs to list_r, doesn't belong to either list) print an appropriate message to the screen.
#
# HINT: If the creation of list_p and list_r is confusing, add print statements to view the two lists and run the cell 3-4 times to see some of the possible situations

# %%
### create lists DO NOT CHANGE
str_choices = [["Introduction", "Intro"], ["Intro", "Introduction"], ["Intro", "Intro"]]
str_indices = np.random.choice([0, 1, 2])
start_str = str_choices[str_indices]

list_p = [start_str[0], "to", "Python"]
list_r = [start_str[1], "to", "R"]

### Your solution below
# Define the keyword variable
keyword = "Introduction"

# Check which list the keyword belongs to
if keyword in list_p:
    print("The keyword belongs to list_p")
elif keyword in list_r:
    print("The keyword belongs to list_r")
else:
    print("The keyword does not belong to either list")

print()
# Optional: Display lists to check keyword manually
print("list_p:", list_p)
print("list_r:", list_r)
# Out:
# The keyword does not belong to either list
#
# list_p: ['Intro', 'to', 'Python']
# list_r: ['Intro', 'to', 'R']

# %% [markdown]
# <font size = "5">
#
# 2. Generate a vector of values and plot it
#
# <font size = "3">
#
# - Below, two lists are defined containing values of $x_k$ and $y_k$
#
# ```python
#     coord_x = [1,4, 0, -1, 20, 40]
#     coord_y = [2,2, 0, 10, 0, 1]
# ```
#
# - Create a vector (**vector always means numpy array**) ```hypotenuse_sqr``` with elements $h_k$ defined by the formula
#
# $\qquad h_k = x_k^2 + y_k^2$
#
# - You **should not** define it manually: so "hypoteneuse_sqr = np.array([5, 20, 0, 101, 400, 1601])" is not an acceptable answer
#
# - Produce a **histogram** with the elements of ```hypotenuse_sqr``` on the horizontal axis
# - Label the axes and the title
# - Change the color to "orange", "green" or "purple" (you choose)
# - Make sure the plot appears in an output cell
#
# Hint: Most mathematical operations are defined for Numpy arrays, which allows you to avoid loops
#
# Hint: type "help(plt.hist)" to see which argument is used to change color

# %%
coord_x = [1,4, 0, -1, 20, 40]
coord_y = [2,2, 0, 10, 0, 1]

### Your solution below
# Calculate hypotenuse squared using list comprehension
hypotenuse_sqr = [coord_x[i]**2 + coord_y[i]**2 for i in range(len(coord_x))]
hypotenuse_sqr = np.array(hypotenuse_sqr)
print(hypotenuse_sqr)

# Alternative approach using numpy arrays
coord_x2 = np.array(coord_x)
coord_y2 = np.array(coord_y)
hypotenuse_sqr2 = coord_x2**2 + coord_y2**2
print(hypotenuse_sqr2)

# Create the histogam of hypotenuse_sqr
plt.figure()
plt.hist(hypotenuse_sqr, color = "orange")
plt.xlabel("Hypotenuse Squared")
plt.ylabel("Frequency")
plt.title("Histogram of Hypotenuse Squared")
plt.show()
# Out:
# [   5   20    0  101  400 1601]
# [   5   20    0  101  400 1601]

# %% [markdown]
# <font size = "5">
#
# 3. Histograms of random variables
#
# <font size = "3">
#
# - Let $n = 500$
# - Generate "vec_x" from a normal distribution with (loc = 0,scale = 1,size = n)
# - Generate "vex_z" from a normal distribution with (loc = 5,scale = 1,size = n)
# - Plot two **histograms** on a single row using the ```plt.subplots``` syntax
#     - Label the axes and title
#     - Each graph should have its axes labeled, and should have their own title
#
# Hint: If you can't remember how subplots works, generate two individual plots for partial credit

# %%
n = 500
# Did not set seed; the result will vary each time

### Your solution below:
# Generate vec_x and vec_z from normal distributions
vec_x = np.random.normal(loc = 0, scale = 1, size = n)
vec_z = np.random.normal(loc = 5, scale = 1, size = n)

# Plot histograms of vec_x and vec_z side by side (subplots)
plt.figure()
plt.subplot(1, 2, 1) # Initialize subplot 1
plt.hist(vec_x, color = "blue")
plt.title("Histogram of vec_x")
plt.xlabel("Value")
plt.ylabel("Frequency")

plt.subplot(1, 2, 2) # Initialize subplot 2 
plt.hist(vec_z, color = "green")
plt.title("Histogram of vec_z")
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.tight_layout()
plt.show()

# %% [markdown]
# <font size = "5">
#
# 4. Combine information across datasets
#
# <font size = "3">
#
# - Read the dataset "/data_quiz_1/germany_co2_emissions.csv" and store it as "data_germany"
# - View the dataset, and see what variables it contains
# - Create a **scatter plot** of CO2 emissions with the following characteristics
#     - The yearly variable on the x-axis.
#     - Germany's CO2 emissions on the y-axis.
#     - Label the axes

# %%
### Your solution below:
import os 
# print(os.getcwd())

# Set the working directory to obtain data file
os.chdir("/Users/joycheng/Documents/GitHub/QTM151/quiz1_section1")

# Load the germany_co2_emissions dataset
data_germany = pd.read_csv("data_quiz_1/germany_co2_emissions.csv")

# View the dataset 
display(data_germany.head())

# Check variables in dataset
print("The dataset variables: ", data_germany.columns.tolist())

# Create the scatter plot of year and total_emissions
plt.figure()
plt.scatter(x = data_germany["year"], y = data_germany["total_emissions"])
plt.xlabel("Year")
plt.ylabel("Total CO2 Emissions")
plt.title("Total CO2 Emissions in Germany Over Years")
plt.show()
# Out:
#    year  total_emissions
# 0  1990         955310.0
# 1  1991         932550.0
# 2  1992         892820.0
# 3  1993         887060.0
# 4  1994         875900.0
# The dataset variables:  ['year', 'total_emissions']

# %% [markdown]
# <font size = "5">
#
# 5. Loop through dfferent variables and plot
#
#
# <font size = "3">
#
# - Read the dataset "data_quiz_1/wdi_ageprop_2020.csv"
# - Create a list of variable names with the following elements:
#
# ```python
#     list_varnames = ["percent_ages0to14","percent_ages15to64"]
# ```
#
# - Run a for loop that computes the mean for each variable and print it on screen.
#
# Hint: Computing the mean of a column/variable from a Pandas dataset is just like computing the mean of a Numpy array

# %%
### Your solution below:
# Load the wdi_ageprop_2020 dataset
wdi_ageprop = pd.read_csv("data_quiz_1/wdi_ageprop_2020.csv")

# View the dataset
display(wdi_ageprop.head())

# Create a list of variable names 
list_varnames = ["percent_ages0to14","percent_ages15to64"]

for idx in list_varnames:
    mean_value = wdi_ageprop[idx].mean()
    print(f"The mean of {idx} is {mean_value:.2f}") 

print()
# Alternative approach using DataFrame mean method
wdi_ageprop_means = wdi_ageprop[list_varnames].mean()
print(wdi_ageprop_means)

# Alternative approach vis loop in range(len())
for idx in range(len(list_varnames)):
    mean_value = wdi_ageprop[list_varnames[idx]].mean()
    print(f"The mean of {list_varnames[idx]} is {mean_value:.2f}")
# Out:
#      year yearcode     countryname countrycode  percent_ages0to14  \
# 0  2020.0   YR2020     Afghanistan         AFG          43.807912
# 1  2020.0   YR2020         Albania         ALB          16.471519
# 2  2020.0   YR2020         Algeria         DZA          30.647083
# 3  2020.0   YR2020  American Samoa         ASM          28.198272
# 4  2020.0   YR2020         Andorra         AND          13.334620
#
#    percent_ages15to64
# 0           53.775135
# 1           67.706368
# 2           63.335447
# 3           65.347810
# 4           72.470399
# The mean of percent_ages0to14 is 26.91
# The mean of percent_ages15to64 is 63.68
#
# percent_ages0to14     26.906571
# percent_ages15to64    63.684652
# dtype: float64
# The mean of percent_ages0to14 is 26.91
# The mean of percent_ages15to64 is 63.68

# %% [markdown]
# <font size = "5">
#
# 6. Run loop through different datasets and compute statistics
#
# <font size = "3">
#
# - Create a list with the ".csv" dataset names of two countries of your choice. For example
#
# ```python
#     ["data_quiz_1/name1.csv","data_quiz_1/name2.csv"]
# ```
#
# - Create an empty list called ``` list_emissions ```
#
# - Run a for-loop over the list of dataset names. Inside the loop:
#     - Read the corresponding ".csv" dataset.
#     - Compute the mean of "total_emissions" for each respective country, <br>
#     and store it as an element of ```list_emissions```
#
# - After the loop, print ```list_emissions```
#
# HINT: Use ```.append()``` (See Lecture 5-supplement or Lecture 7)

# %%
### Your solution below:
data_list = ["data_quiz_1/china_co2_emissions.csv", "data_quiz_1/korea_rep_co2_emissions.csv"]

# Initialize an empty list to store mean emissions
list_emissions = []

# Loop through each file in data_list
for file in data_list:
    data = pd.read_csv(file) # Load the dataset

    # Compute the mean of total_emissions
    mean_emission = data["total_emissions"].mean()
    
    # Append the mean as an element to list_emissions
    list_emissions.append(mean_emission)

# Print the list of mean emissions
print("Mean CO2 emissions for China and Korea Rep:\n", list_emissions)
# Out:
# Mean CO2 emissions for China and Korea Rep:
#  [3599957.523613542, 287606.4942740235]

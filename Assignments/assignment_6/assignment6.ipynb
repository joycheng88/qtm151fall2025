# %% [markdown]
# # Assignment 6

# %% [markdown]
# <font size = "5">
#
# Import the "pandas" and "matplotlib.pyplot" libraries (and any other libraries if you would like)

# %%
# Import relevant libraries
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# <font size = "5">
#
# (a) Functions
#
# <font size = "3">
#
# - Read in the dataset named "features.csv".
# - Create a ``` lambda ``` function that checks if weight $≤$ 3000
# - Using the Pandas method ``.apply()``, create a new Series that shows ``True`` if weight $≤$ 3000 and ``False``if weight > 3000.
# - Using the ``.shape`` attribute, print the number of cars that have weight $≤$ 3000.
#
# **Hint**: A Pandas Series has only one dimension, so the ``.shape`` attribute is a "tuple" with only one element. In order to get a single integer, type ``your_variable_name.shape[0]``

# %%
# Write your answer here:
# Load the dataset "features.csv"
df_features = pd.read_csv("data/features.csv")
display(df_features.head())

# Create a lambda function to check if weight <= 3000
check_weight = lambda weight: weight <= 3000 

# Create a new Series with True/False values
weight_condition = df_features["weight"].apply(check_weight)
display(weight_condition.head())

# Print the number of cars that have weight <= 3000 (I keep the .shape attribute approach)
num_cars = weight_condition[weight_condition == True].shape[0]
print("Number of cars with weight less than or equal to 3000:", num_cars)
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration vehicle_id
# 0  18.0          8           307        130    3504          12.0  C-1689780
# 1  15.0          8           350        165    3693          11.5  B-1689791
# 2  18.0          8           318        150    3436          11.0  P-1689802
# 3  16.0          8           304        150    3433          12.0  A-1689813
# 4  17.0          8           302        140    3449          10.5  F-1689824
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# Name: weight, dtype: bool
# Number of cars with weight less than or equal to 3000: 230

# %% [markdown]
# <font size = "5">
#
# (b) Subsetting Data
#
# <font size = "3" >
#
# - Read in the dataset named "features.csv".
# - Define a global variable called ```threshold``` that takes the value 2500 <br>
# - Subset the data to get one dataset with weight $>$ threshold and <br>
# another with weight $\le$ threshold. Use the ```.query()``` function.
# - Compute the mean acceleration for each of these datasets, printing these values to the screen<br>
#
# Note: Review how to define a global variable inside ```.query()```

# %%
# Write your answer here:
# Define global variable threshold 
threshold = 2500

# Subset the data for heavy and light cars based on threshold 
df_heavy_cars = df_features.query("weight > @threshold")
df_light_cars = df_features.query("weight <= @threshold")

# Compute mean acceleration for each dataset
mean_acc_heavy = df_heavy_cars["acceleration"].mean()
mean_acc_light = df_light_cars["acceleration"].mean()

# Print the results
print(f"Mean acceleration for cars with weight greater than the threshold: {mean_acc_heavy:.2f}")
print(f"Mean acceleration for cars with weight less than or equal to the threshold: {mean_acc_light:.2f}")
# Out:
# Mean acceleration for cars with weight greater than the threshold: 15.00
# Mean acceleration for cars with weight less than or equal to threshold: 16.54

# %% [markdown]
# <font size = "5">
#
# (c) Use sorting + ".iloc[]"
#
# <font size = "3">
#
# - Read the "fifa23_players_basic.csv" dataset
# - Use ".sort_values()" to order the "Age" column from oldest to youngest<br>
# - Get a subset with the 5 oldest players

# %%
# Write your answer here:
# Load the dataset "fifa23_players_basic.csv"
df_fifa = pd.read_csv("data/fifa23_players_basic.csv")

df_fifa = df_fifa.sort_values("Age", ascending = False)

df_fifa_oldest = df_fifa.iloc[:5,]
display(df_fifa_oldest)
# Out:
#           Known As          Full Name  Overall  Potential  Value(in Euro)  \
# 592      G. Buffon   Gianluigi Buffon       79         79         1900000
# 13548     S. Lukić       Stojan Lukić       62         62           45000
# 3276    S. Torrico  Sebastián Torrico       72         72          250000
# 15525  J. Szmatuła     Jakub Szmatuła       59         59           25000
# 10851    M. Galezo      Moisés Galezo       64         64               0
#
#       Positions Played Best Position             Nationality  \
# 592                 GK            GK                   Italy
# 13548               GK            GK  Bosnia and Herzegovina
# 3276                GK            GK               Argentina
# 15525               GK            GK                  Poland
# 10851               CB            CB               Venezuela
#
#                                              Image Link  Age  ...  \
# 592    https://cdn.sofifa.net/players/001/179/23_60.png   44  ...
# 13548  https://cdn.sofifa.net/players/213/483/23_60.png   42  ...
# 3276   https://cdn.sofifa.net/players/216/692/23_60.png   42  ...
# 15525  https://cdn.sofifa.net/players/155/422/23_60.png   41  ...
# 10851  https://cdn.sofifa.net/players/265/721/23_60.png   41  ...
#
#        Preferred Foot  Weak Foot Rating  Skill Moves  \
# 592             Right                 2            1
# 13548           Right                 2            1
# 3276            Right                 2            1
# 15525           Right                 3            1
# 10851           Right                 3            2
#
#        International Reputation National Team Name  \
# 592                           4                  -
# 13548                         1                  -
# 3276                          1                  -
# 15525                         1                  -
# 10851                         1                  -
#
#                   National Team Image Link  National Team Position  \
# 592    https://cdn.sofifa.net/flags/it.png                       -
# 13548                                    -                       -
# 3276   https://cdn.sofifa.net/flags/ar.png                       -
# 15525  https://cdn.sofifa.net/flags/pl.png                       -
# 10851  https://cdn.sofifa.net/flags/ve.png                       -
#
#       National Team Jersey Number Attacking Work Rate Defensive Work Rate
# 592                             -              Medium              Medium
# 13548                           -              Medium              Medium
# 3276                            -              Medium              Medium
# 15525                           -              Medium              Medium
# 10851                           -              Medium                High
#
# [5 rows x 32 columns]

# %% [markdown]
# <font size = "5">
#
# (d) Use queries + global variables
#
# <font size = "3">
#
# - Read the "fifa23_players_basic.csv" dataset
# - Compute the mean of the column "Weight(in kg)"
# and store it as a variable
# - Subset the players whose Weight in kilograms is stricly large than this mean value
#   using ".query()"
#
#
# HINT: Remember that there is a special syntax for when using column names inside the .query() method (the backtick `)

# %%
# Write your answer here: 
mean_player_weight = df_fifa["Weight(in kg)"].mean()
print(f"Mean player weight: {mean_player_weight:.2f} kg")

df_heavier_players = df_fifa.query("`Weight(in kg)` > @mean_player_weight")
display(df_heavier_players.head())
# Out:
# Mean player weight: 75.17 kg
#           Known As          Full Name  Overall  Potential  Value(in Euro)  \
# 592      G. Buffon   Gianluigi Buffon       79         79         1900000
# 13548     S. Lukić       Stojan Lukić       62         62           45000
# 3276    S. Torrico  Sebastián Torrico       72         72          250000
# 15525  J. Szmatuła     Jakub Szmatuła       59         59           25000
# 10851    M. Galezo      Moisés Galezo       64         64               0
#
#       Positions Played Best Position             Nationality  \
# 592                 GK            GK                   Italy
# 13548               GK            GK  Bosnia and Herzegovina
# 3276                GK            GK               Argentina
# 15525               GK            GK                  Poland
# 10851               CB            CB               Venezuela
#
#                                              Image Link  Age  ...  \
# 592    https://cdn.sofifa.net/players/001/179/23_60.png   44  ...
# 13548  https://cdn.sofifa.net/players/213/483/23_60.png   42  ...
# 3276   https://cdn.sofifa.net/players/216/692/23_60.png   42  ...
# 15525  https://cdn.sofifa.net/players/155/422/23_60.png   41  ...
# 10851  https://cdn.sofifa.net/players/265/721/23_60.png   41  ...
#
#        Preferred Foot  Weak Foot Rating  Skill Moves  \
# 592             Right                 2            1
# 13548           Right                 2            1
# 3276            Right                 2            1
# 15525           Right                 3            1
# 10851           Right                 3            2
#
#        International Reputation National Team Name  \
# 592                           4                  -
# 13548                         1                  -
# 3276                          1                  -
# 15525                         1                  -
# 10851                         1                  -
#
#                   National Team Image Link  National Team Position  \
# 592    https://cdn.sofifa.net/flags/it.png                       -
# 13548                                    -                       -
# 3276   https://cdn.sofifa.net/flags/ar.png                       -
# 15525  https://cdn.sofifa.net/flags/pl.png                       -
# 10851  https://cdn.sofifa.net/flags/ve.png                       -
#
#       National Team Jersey Number Attacking Work Rate Defensive Work Rate
# 592                             -              Medium              Medium
# 13548                           -              Medium              Medium
# 3276                            -              Medium              Medium
# 15525                           -              Medium              Medium
# 10851                           -              Medium                High
#
# [5 rows x 32 columns]

# %% [markdown]
# <font size = "5">
#
# (e) Plot by Category
#
# <font size = "3">
#
# Read in the dataset named "wdi_urban.csv".
#
#   This contains data from 1980 and 2020.
#
# - **Create an array with the unique values of "year" using the ``Pandas`` function ``unique``**
#
# - **Create a plot with a ...**
#     - Histogram of "prop_urbanpopulation" (proportion of urban population) for each year
#     - Set the histogram option `alpha = 0.5` for transparency
#     - All the histograms should be overlapping on the same plot
#     - Create a legend with the list of years
#     - Label the axes and the title
#
# **Hint**: The procedure will be similar (but not exactly the same!) as when we created a scatter plot of cars with different numbers of cylinders in Lecture 11

# %%
# your answer here
df_wdi_urban = pd.read_csv("data/wdi_urban.csv")
display(df_wdi_urban.head())

years = df_wdi_urban["year"].unique()

# Create a histogram of prop_urbanpopulation for each year
plt.figure()
for year in years:
    df_year_subset = df_wdi_urban.query("year == @year")["prop_urbanpopulation"]
    plt.hist(df_year_subset, alpha=0.5, label=str(year))

# Add legend, labels, and title
plt.legend(title="Year")
plt.xlabel("Proportion of Urban Population")
plt.ylabel("Frequency")
plt.title("Histogram of Proportion of Urban Population by Year")
plt.show()
# Out:
#    year yearcode     countryname countrycode  prop_urbanpopulation
# 0  1980   YR1980     Afghanistan         AFG                15.995
# 1  1980   YR1980         Albania         ALB                33.762
# 2  1980   YR1980         Algeria         DZA                43.542
# 3  1980   YR1980  American Samoa         ASM                74.330
# 4  1980   YR1980         Andorra         AND                92.064
